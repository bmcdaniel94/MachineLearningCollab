# %%
sensitivity=0.9545,
specificity=0.1071,
prevelance=0.44
    
"""
Computes Bayes' rule
"""
p_bin = prevelance
p_non_bin = 1-prevelance
p_pos_bin = sensitivity
p_neg_bin = specificity
p_pos_non_bin = (1-specificity)
    
num = p_pos_bin*p_bin
den = p_pos_bin*p_bin+p_pos_non_bin*p_non_bin
    
prob = num/den

print(prob)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-3a4c4de41203> in <module>()
#      11 p_pos_bin = sensitivity
#      12 p_neg_bin = specificity
# ---> 13 p_pos_non_bin = (1-specificity)
#      14
#      15 num = p_pos_bin*p_bin
#
# TypeError: unsupported operand type(s) for -: 'int' and 'tuple'
